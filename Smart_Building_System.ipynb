# %% [markdown]
# <a href="https://colab.research.google.com/github/arif-sakib330/Smart-Building-System/blob/main/Smart_Building_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-49f936ee-787d-41ab-8f26-8a7faa41eb40" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49f936ee-787d-41ab-8f26-8a7faa41eb40">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip /content/archive.zip
# Out:
# Archive:  /content/archive.zip
#   inflating: KETI/413/co2.csv
#   inflating: KETI/413/humidity.csv
#   inflating: KETI/413/light.csv
#   inflating: KETI/413/pir.csv
#   inflating: KETI/413/temperature.csv
#   inflating: KETI/415/co2.csv
#   inflating: KETI/415/humidity.csv
#   inflating: KETI/415/light.csv
#   inflating: KETI/415/pir.csv
#   inflating: KETI/415/temperature.csv
#   inflating: KETI/417/co2.csv
#   inflating: KETI/417/humidity.csv
#   inflating: KETI/417/light.csv
#   inflating: KETI/417/pir.csv
#   inflating: KETI/417/temperature.csv
#   inflating: KETI/419/co2.csv
#   inflating: KETI/419/humidity.csv
#   inflating: KETI/419/light.csv
#   inflating: KETI/419/pir.csv
#   inflating: KETI/419/temperature.csv
#   inflating: KETI/421/co2.csv
#   inflating: KETI/421/humidity.csv
#   inflating: KETI/421/light.csv
#   inflating: KETI/421/pir.csv
#   inflating: KETI/421/temperature.csv
#   inflating: KETI/422/co2.csv
#   inflating: KETI/422/humidity.csv
# ...

# %%
import pandas as pd
df = pd.read_csv("KETI/664/co2.csv")
df.head()
# Out:
#    1377299105   347.00
# 0  1377299126    342.0
# 1  1377299130    342.0
# 2  1377299133    339.0
# 3  1377299138    331.0
# 4  1377299143    338.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['1377299105'].plot(kind='hist', bins=20, title='1377299105')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1[' 347.00'].plot(kind='hist', bins=20, title=' 347.00')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='1377299105', y=' 347.00', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
import pandas as pd
df = pd.read_csv("KETI/648/pir.csv")
df.head()
# Out:
#    1377285874   0.00
# 0  1377296004   29.0
# 1  1377296014   28.0
# 2  1377296016   30.0
# 3  1377296017   30.0
# 4  1377296020   30.0

# %%
import pandas as pd
df = pd.read_csv("KETI/413/humidity.csv")
df.head()
# Out:
#    1377299107   45.34
# 0  1377299108   45.34
# 1  1377299126   45.34
# 2  1377299131   45.31
# 3  1377299136   45.34
# 4  1377299141   45.34
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_14['1377299107'].plot(kind='hist', bins=20, title='1377299107')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15[' 45.34'].plot(kind='hist', bins=20, title=' 45.34')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16.plot(kind='scatter', x='1377299107', y=' 45.34', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
import pandas as pd
df = pd.read_csv("KETI/413/humidity.csv")
df.head()
# Out:
#    1377299107   45.34
# 0  1377299108   45.34
# 1  1377299126   45.34
# 2  1377299131   45.31
# 3  1377299136   45.34
# 4  1377299141   45.34
